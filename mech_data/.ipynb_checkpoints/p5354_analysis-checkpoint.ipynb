# %% [raw]
# Name:  p5354PresFilm3-21
# Number of records: 7080
# Number of columns: 3
#
#
# -------------------------------------------------
# |           Name|           Unit|        Records|
# -------------------------------------------------
# |       hor_disp|         micron|           7080|
# |      HorStress|            MPa|           7080|
# |           Time|            sec|           7080|
# -------------------------------------------------

# %%
import matplotlib.pyplot as plt
import numpy as np
# import scipy.signal as sig

# %%
dat = np.load('p5354_data_npz.npz')['arr_0']

[Hdisp, Hload, time] = list(map(lambda x: dat[:,x], [0,1,2]))

del dat

# %%
# %matplotlib ipympl

fig, ax1 = plt.subplots(1,1,figsize=(15,8)) #,dpi=300)

ax1.plot(Hdisp[500:], Hload[500:], c='k',ls='-',lw=1)

z = np.polyfit(Hdisp[loads[aa,0]:loads[aa,1]-145] - Hdisp[loads[aa,0]], Hload[loads[aa,0]:loads[aa,1]-145], 7)
p = np.poly1d(z)
xp = np.linspace(0, 4500, 1000)

ax1.set_xlabel('Hor. Disp. ($\mu m$)')
ax1.set_ylabel('Hor Load (MPa)')
# ax1.set_yscale('log')
# ax1.set_xscale('log')
# ax2.set_ylabel('permeability ($m^2$)')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e06e2b1bce49> in <module>
#       5 ax1.plot(Hdisp[500:], Hload[500:], c='k',ls='-',lw=1)
#       6
# ----> 7 z = np.polyfit(Hdisp[loads[aa,0]:loads[aa,1]-145] - Hdisp[loads[aa,0]], Hload[loads[aa,0]:loads[aa,1]-145], 7)
#       8 p = np.poly1d(z)
#       9 xp = np.linspace(0, 4500, 1000)
#
# NameError: name 'aa' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

def func(x, a, b, c):
#     return a * np.exp(-b * x) + c
  return a * np.log(b * x) + c
, 
x = Hdisp[600:]   # changed boundary conditions to avoid division by 0
y = Hload[600:]
# yn = Hload[500:] + 0.2*np.random.normal(size=len(x))

popt, pcov = curve_fit(func, x, y)

plt.figure()
plt.plot(x, y, 'ko', label="Original Noised Data")
plt.plot(x, func(x, *popt), 'r-', label="Fitted Curve")

plt.legend()
plt.show()
# Out:
# /Users/clay/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in log
#   import sys
# /Library/Python/3.7/site-packages/scipy/optimize/minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
# %matplotlib inline

fig, ax1 = plt.subplots(1,1,figsize=(15,8),dpi=300)
ax2 = ax1.twinx()

ax1.plot(time[500:], Hload[500:], c='b',ls='-',lw=1)
ax2.plot(time[500:], Hdisp[500:], c='r',ls='-',lw=1)

ax2.spines['left'].set_color('blue')
ax1.tick_params(axis='y', colors='blue')

ax2.spines['right'].set_color('red')
ax2.tick_params(axis='y', colors='red')

ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Hor. Load (MPa)', color='b')
ax2.set_ylabel('Hor. Disp. ($\mu m$)', color='r')
# ax2.set_ylabel('permeability ($m^2$)')

plt.show()

# %%
# %matplotlib ipympl
# %matplotlib inline

fig, ax1 = plt.subplots(1,1,figsize=(15,8),dpi=300)

for aa in range(1):
    ax1.plot(time[loads[aa,0]:loads[aa,1]], Hload[loads[aa,0]:loads[aa,1]]/Hdisp[loads[aa,0]:loads[aa,1]], c='k',ls='-',lw=1)

# ax2.spines['left'].set_color('blue')
# ax1.tick_params(axis='y', colors='blue')

# ax2.spines['right'].set_color('red')
# ax2.tick_params(axis='y', colors='red')

ax1.set_xlabel('Time (s)')
ax1.set_ylabel('$MPa/\mu m$')
# ax2.set_ylabel('Hor. Disp. ($\mu m$)', color='r')
# ax2.set_ylabel('permeability ($m^2$)')

plt.show()

# %%
loads = np.array([[543,831], [1282, 1560], [3608, 4005], [4149, 4536], [4678, 5004], [5165, 5513], [5640, 5953], [6047, 6555], [6671, 7055]]);

# %%
x = Hdisp[loads[0,0]:loads[0,1]-145] - Hdisp[loads[0,0]]
y = Hload[loads[0,0]:loads[0,1]-145]

# xp = np.linspace(0, 2500, 1000)

# %%
# %matplotlib ipympl
# %matplotlib inline
# from scipy.optimize import curve_fit
fig, ax1 = plt.subplots(1,1,figsize=(15,8) ,dpi=300)

for aa in range(9):
    ax1.plot(Hdisp[loads[aa,0]:loads[aa,1]], Hload[loads[aa,0]:loads[aa,1]], ls='-',lw=1)
    
#     def func(x, a, b, c):
#             return a * np.exp(-b * x) + c


#     y = func(x, 2.5, 1.3, 0.5)


# popt, pcov = curve_fit(func, x, yn)
    
#     z = np.polyfit(Hdisp[loads[aa,0]:loads[aa,1]-145], np.log(Hload[loads[aa,0]:loads[aa,1]-145]), 1)
# #     p = np.poly1d(z)
    
#     xp = np.linspace(1, 2200, 1000)
    
#     ax1.plot(xp, np.exp(z[1])*np.exp(z[0]*xp), c='r', ls='-',lw=1)

ax1.set_xlim([3500,5900])
ax1.set_xlabel('Hor. Disp. ($\mu m$)')
ax1.set_ylabel('Hor Load (MPa)')

# ax1.set_ylim([0,25])
# ax1.set_xlim([0,2200])
# ax2.set_ylabel('permeability ($m^2$)')

plt.show()
